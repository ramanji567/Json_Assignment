# %% [markdown]
# <a href="https://colab.research.google.com/github/ramanji567/Json_Assignment/blob/main/Json_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1:Build a JSON Structure

# %%
import json
user_profile ={
    "name":"Ramanjineyulu",
    "age":23,
    "email":"vallepuramanjineyulu5@gmail.com",
    "is_active":True,
    "skill":["python","sql","numpy","pandas"]
}
data = json.dumps(user_profile)
print(f"JSON string:{data}")
print(type(data))
# Out:
# JSON string:{"name": "Ramanjineyulu", "age": 23, "email": "vallepuramanjineyulu5@gmail.com", "is_active": true, "skill": ["python", "sql", "numpy", "pandas"]}
# <class 'str'>

# %% [markdown]
# Task 2:Parse An API Response

# %%
import json
Api_response ={
    "status":"success",
    "data":{"user_id":101,
            "username":"alex99",
            "score":87.5}
}
username = Api_response["data"]["username"]
score = Api_response["data"]["score"]
print(f"username:{username}")
print(f"score:{score}")
print(f"A Message: user {username} scored {score} points")
# Out:
# username:alex99
# score:87.5
# A Message: user alex99 scored 87.5 points

# %% [markdown]
# Task 3:Handle the nested Json

# %%
import json
data = {
    "name":"priya",
    "address":{
        "city":"bengaluru",
        "state":"Karnataka",
        "zip":"560001"
    }
}
json_str = json.dumps(data)
print(f"city:{data["address"]["city"]}")
print(f"Zip:{data["address"]["zip"]}")
data["address"]["country"]="India"
print(data)
# Out:
# city:bengaluru
# Zip:560001
# {'name': 'priya', 'address': {'city': 'bengaluru', 'state': 'Karnataka', 'zip': '560001', 'country': 'India'}}
